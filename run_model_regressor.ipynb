# %% [markdown]
# ## Running Abil

# %%
#paths:
import os
#handling data:
import pandas as pd
from yaml import load
from yaml import CLoader as Loader
from datetime import datetime
#abil functions:
from abil.tune import ModelTuner as tune
from abil.predict import ModelPredictor as predict
from abil.post import AbilPostProcessor as post

# %%
#define directories (using abspath to avoid long file names)
root = os.getcwd()
conffile = os.path.abspath(os.path.join(root,'regressor.yml'))

#load model configuration
with open(conffile, 'r') as f:
    model_config = load(f, Loader=Loader)

# %%
#load training data
targets = pd.read_csv(os.path.join(root,model_config['targets']))
d = pd.read_csv(os.path.join(root,model_config['training']))

#define target:
target =  targets['Target'][0]

#define predictors based on YAML:
predictors = model_config['predictors']
d = d.dropna(subset=predictors)

#split training data in X_train and y
y = d[target]
X_train = d[predictors]

print("finished loading data")
# Out:
# finished loading data

# %%
#setup model:
m = tune(X_train, y, model_config)

#run model:
m.train(model='rf', log='both')
m.train(model='knn', log='both')
m.train(model='xgb', log='both')
# Out:
# beginning init
# length of y: 179
# training regressor
# {'regressor__estimator__n_estimators': [250], 'regressor__estimator__max_features': [0.5, 1.0], 'regressor__estimator__max_depth': [25, 51], 'regressor__estimator__min_samples_leaf': [1, 5], 'regressor__estimator__max_samples': [0.9, 1.0]}
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# best fit: log
# exported model to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/model/rf/Primary_Production_reg.sav
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# exported scoring to:  /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/scoring/rf/Primary_Production_reg.sav
# reg rRMSE: 76%
# reg rMAE: 44%
# reg R2: 0.46
# execution time: 0.0 seconds
# training regressor
# {'regressor__estimator__max_samples': [0.5, 1.0], 'regressor__estimator__max_features': [2, 4], 'regressor__estimator__estimator__n_neighbors': [3, 4], 'regressor__estimator__estimator__p': [1, 2], 'regressor__estimator__estimator__weights': ['distance']}
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.2s remaining:    0.8s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.3s finished
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# best fit: log
# exported model to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/model/knn/Primary_Production_reg.sav
# exported scoring to:  /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/scoring/knn/Primary_Production_reg.sav
# reg rRMSE: 81%
# reg rMAE: 49%
# reg R2: 0.41
# execution time: 0.0 seconds
# training regressor
# {'regressor__estimator__n_estimators': [100], 'regressor__estimator__learning_rate': [0.1, 0.2], 'regressor__estimator__max_depth': [25, 51], 'regressor__estimator__subsample': [0.5, 1.0], 'regressor__estimator__colsample_bytree': [0.9, 1.0], 'regressor__estimator__reg_alpha': [0, 0.1], 'regressor__estimator__gamma': [0]}
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# best fit: log
# exported model to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/model/xgb/Primary_Production_reg.sav
# exported scoring to:  /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/scoring/xgb/Primary_Production_reg.sav
# reg rRMSE: 73%
# reg rMAE: 43%
# reg R2: 0.40
# execution time: 0.0 seconds
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.2s remaining:    0.7s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.2s finished

# %%
#load prediction data:
X_predict =  pd.read_csv(os.path.join(root,model_config['prediction']))
X_predict.set_index(["time", "depth", "lat", "lon"], inplace=True)
X_predict = X_predict[predictors]

#setup model
m = predict(X_train, y, X_predict, model_config)

#predict model
m.make_prediction()
# Out:
# initialized prediction
# number of models in ensemble: 3
# predicting regressor
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# finished exporting summary stats to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/rf/Primary_Production.nc
# predicting regressor
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# finished exporting summary stats to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/xgb/Primary_Production.nc
# predicting regressor
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# finished exporting summary stats to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/knn/Primary_Production.nc
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/mv23682/miniconda3/envs/abil-tutorial-env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# finished exporting summary stats to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/ens/Primary_Production.nc
# finished
# execution time: 110.99096822738647 seconds
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    2.3s finished

# %%
target_names = targets['Target'].values
target_subset = target_names[:1] # subset for estimate_applicability and merge_obs
current_date = datetime.today().strftime('%Y-%m-%d')

def do_post(statistic):
    m = post(X_train, y, X_predict, model_config, statistic)
    
    if statistic == "mean":
        print('begin estimate_applicability')
        m.estimate_applicability(target_subset)

        print('begin merge_obs')
        m.merge_obs(current_date,target_subset)

    print('begin export_ds')
    m.export_ds(current_date)

    print('begin integration')
    magnitude_conversion = 1e-21
    molar_mass = 12.01
    integ = m.integration(m, magnitude_conversion=magnitude_conversion,molar_mass=molar_mass,rate=True)
    if statistic == "mean":
        integ.integrated_totals(target_names)
    else:
        integ.integrated_totals(target_subset)

    print('do_post for: ', statistic, ' complete')

# %%
do_post(statistic="mean")
do_post(statistic="ci95_UL")
do_post(statistic="ci95_LL")
# Out:
# merging... /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/ens
# finished merging NetCDF files
# Model configuration exported to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/model_config.yml
# the target is: Primary_Production
# finished merging parameters
# the target is: Primary_Production
# finished merging parameters
# the target is: Primary_Production
# finished merging parameters
# models included in merge performance! ['rf', 'xgb', 'knn']
# finished merging performance
# finished merging performance
# finished merging performance
# finished merging performance
# begin estimate_applicability
# begin merge_obs
#                        Primary_Production  Primary_Production_mod  \
# lat  lon   depth time
# 46.0 -8.0  0.0   6                1535.14             1585.306087
#            5.0   6                1620.71             1545.337414
#            15.0  6                1548.27             1392.863808
#            20.0  6                1236.99             1157.551605
# 48.0 -10.0 0.0   4                6891.24             5821.619100
#
#                        Primary_Production_resid
# lat  lon   depth time
# 46.0 -8.0  0.0   6                   -50.166087
#            5.0   6                    75.372586
#            15.0  6                   155.406192
#            20.0  6                    79.438395
# 48.0 -10.0 0.0   4                  1069.620900
# exported d to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/2026-04-28_obs.csv
# training merged with predictions
# begin export_ds
# export_ds
# dataframe:                     Primary_Production
# time depth lat lon
# 1    0     45  -60         1452.624234
#                -59         1319.090660
#                -58         1294.104908
#                -57         1150.953827
#                -56         1237.827106
#                     Primary_Production
# time depth lat lon
# 1    0     45  -60         1452.624234
#                -59         1319.090660
#                -58         1294.104908
#                -57         1150.953827
#                -56         1237.827106
# exported ds to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/2026-04-28_mean.nc
# begin integration
# Processing target: Primary_Production
# Initiate integrated_total
# Final integrated total: 1.4090147215929114
# Exported totals
# do_post for:  mean  complete
# merging... /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/ens
# finished merging NetCDF files
# Model configuration exported to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/model_config.yml
# the target is: Primary_Production
# finished merging parameters
# the target is: Primary_Production
# finished merging parameters
# the target is: Primary_Production
# finished merging parameters
# models included in merge performance! ['rf', 'xgb', 'knn']
# finished merging performance
# finished merging performance
# finished merging performance
# finished merging performance
# begin export_ds
# export_ds
# dataframe:                     Primary_Production
# time depth lat lon
# 1    0     45  -60         1694.912320
#                -59         1687.880403
#                -58         1529.047922
#                -57         1423.240107
#                -56         1493.046032
#                     Primary_Production
# time depth lat lon
# 1    0     45  -60         1694.912320
#                -59         1687.880403
#                -58         1529.047922
#                -57         1423.240107
#                -56         1493.046032
# exported ds to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/2026-04-28_ci95_UL.nc
# begin integration
# Processing target: Primary_Production
# Initiate integrated_total
# Final integrated total: 1.7818324692710767
# Exported totals
# do_post for:  ci95_UL  complete
# merging... /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/predictions/ens
# finished merging NetCDF files
# Model configuration exported to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/model_config.yml
# the target is: Primary_Production
# finished merging parameters
# the target is: Primary_Production
# finished merging parameters
# the target is: Primary_Production
# finished merging parameters
# models included in merge performance! ['rf', 'xgb', 'knn']
# finished merging performance
# finished merging performance
# finished merging performance
# finished merging performance
# begin export_ds
# export_ds
# dataframe:                     Primary_Production
# time depth lat lon
# 1    0     45  -60         1135.885182
#                -59          912.708113
#                -58          938.058681
#                -57          823.837154
#                -56          814.591029
#                     Primary_Production
# time depth lat lon
# 1    0     45  -60         1135.885182
#                -59          912.708113
#                -58          938.058681
#                -57          823.837154
#                -56          814.591029
# exported ds to: /home/mv23682/Documents/Abil_tutorial/ModelOutput/pp_na/posts/2026-04-28_ci95_LL.nc
# begin integration
# Processing target: Primary_Production
# Initiate integrated_total
# Final integrated total: 1.0674868490717688
# Exported totals
# do_post for:  ci95_LL  complete
